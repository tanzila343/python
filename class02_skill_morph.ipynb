# %%
#1
name="keya"
age=22
favourite_color="black"
print(name)
print(age)
print(favourite_color)
#2
print(type(name))
print(type(age))
print(type(favourite_color))
#3
length=7
width=5
area=length*width
print(area)
#4
Bangladeshi_food=[mango,banana,jack_fruit]
print(Bangladeshi_food[0])
print(Bangladeshi_food[-1])
Bangladeshi_food.append("pineapple")
#5
Bangladeshi_food.remove("mango")
pop=Bangladeshi_food.pop()
Bangladeshi_food.sort()
#6
Student = {
    "course_teacher": "keya",
    "course_name":"Theory of Computation",
    "credit": 3
}
#7
Dhaka=(23.777176,90.399452)
print(Dhaka[0])
print(Dhaka[1])
#8
color_rgb={"blue","green","red"}
color_CMY={"Cyan","Yellow","magenta"}
all_color=color_rgb|color_CMY
print(all-color)
common_color=color_rgb & color_CMY
print(common_color)
#9
string_name="keya"
print(string_name[0])
print(string_name[-1])
string_name.upper()
