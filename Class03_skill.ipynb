# %% [markdown]
# <a href="https://colab.research.google.com/github/tanzila343/python/blob/main/Class03_skill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.
age=int(input('enter age:'))
if age>=18:
    print("eligible for vote")
else:
    print("not eligible for vote")
#2.
number=int(input('enter number'))
if number==0:
    print('number zero')
elif number>0:
    print('number is positive')
elif number<0:
    print('number is negative')

#3.
number=int(input("enter number"))
if number%2==0:
    print("number is odd")
else:
    print("number is even")
#4.
age=int(input('enter age:'))
if age>=0 & age<=12:
    print("child")
elif age>=13 & age<=19:
    print("teenager")
elif age>=20 & age<=64:
    print("Adult")
else:
    print("senior")
#4
i=0
sum=0
number=10
for i in number:
    sum=sum+i
print(sum)
#5
fact=1
num=10
for i in num:
    fact=fact*i
print(fact)
#6
for i in range(1, 6):
  for j in range(1, 6):
    mul = i * j
    print(f"{i} × {j} = {mul}")
